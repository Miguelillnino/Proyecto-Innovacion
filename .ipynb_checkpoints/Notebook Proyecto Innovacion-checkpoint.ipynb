# %% [markdown]
# <div style="text-align: center; margin: 50px">
# <h1 style="color: darkblue; text-align: center;">Implementación de máquinas de aprendizaje
# para la reducción de falsos positivos de hiper-intensidades presentes en la materia blanca del cerebro</h1>
# </div>

# %% [markdown]
# <div style="text-align: center; margin: 50px">
# <h1>Miguel de Jesús Martínez Felipe</h1>
# <h1>Jesús Alberto Martínez Castro</h1>
# </div>

# %%
from os import listdir
from os.path import isfile, join
import numpy
import cv2
from matplotlib import pyplot as plt
import pandas as pd
import statistics
import matplotlib.pyplot as plt
from scipy.stats import kurtosis,skew,entropy
from skimage.feature import greycomatrix, greycoprops
from skimage import io, color, img_as_ubyte
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing #Biblioteca para normalizar datos.
from sklearn.model_selection import train_test_split #Biblioteca para divir los datos de entrenamiento.
from keras.models import Sequential #Biblioteca para crear modelos secuenciales.
from keras.layers import Dense #Biblioteca para crear las capas de las redes neuronales (Una capa consta de una función de cálculo de tensor de entrada y tensor de salida).
from tensorflow import keras #Biblioteca para crear optimizadores.
from sklearn.metrics import roc_curve #Biblioteca para determinar datos de la curva característica operativa del receptor (ROC).
from sklearn.metrics import roc_auc_score #Biblioteca para determinar puntuaje de la clasificación de los datos.

column_names = ["Mean", "Variance", "StD","Kurtosis","Max", "Min", "Skewness","Entropy"
                ,"Constrast","Correlation","Energy","Homogeneity","Label"]

# %%
#Funcion que recibe la ruta de un directorio con imágenes y el número de etiqueta de las imágenes (Lesion:1 y No lesion:0)
def ImagesToDataFrame(pathFiles,label):

    listMean = []
    listVariance = []
    listStD = []
    listKurtosis = []
    listMax = []
    listMin = []
    listSkewness = []
    listEntropy = []
    listConstrast = []
    listCorrelation = []
    listEnergy = []
    listHomogeneity = []
    listLabel = []

######################################
######################################
# Se caracterizan las imagenes 
######################################
######################################
    onlyfiles = [ f for f in listdir(pathFiles) if isfile(join(pathFiles,f)) ]
    images = numpy.empty(len(onlyfiles), dtype=object)
    for n in range(0, len(onlyfiles)):
    #     print(join(pathFiles,onlyfiles[n]))
        images[n] = cv2.imread(join(pathFiles,onlyfiles[n]) )
        ######################################
        ######################################
        # Se Binariza la imagen 
        ######################################
        ######################################
        grayImage = cv2.cvtColor(images[n], cv2.COLOR_BGR2GRAY)
        ret,thresh1 = cv2.threshold(grayImage,0,255,cv2.THRESH_BINARY)
        plt.subplot(1,1,1),plt.imshow(thresh1,'gray')
        plt.title('otsu')
        plt.xticks([]),plt.yticks([])
        plt.show()
        # ret,thresh1 = cv2.threshold(images[0], 0, 255,cv2.THRESH_OTSU)
        ######################################
        ######################################
        # Se etiqueta la imagen 
        ######################################
        ######################################
        connectivity = 4  
    
        output = cv2.connectedComponentsWithStats(thresh1, connectivity, cv2.CV_32S)
        (numLabels, labels, stats, centroids) = output
        
    
        # iteración sobre el número de etiquetas de componentes conectados únicos
        for i in range(0, numLabels):
            # Se ignora el primer elemento de etiqutado porque es el fondo
            if i == 0:
                text = "Examinando el componente {}/{} (fondo)".format(
                    i + 1, numLabels)
            # Se examina un componente conectado
            else:
                text = "Examinando el componente {}/{}".format( i + 1, numLabels)
            # Imprime el mensaje de estatus actualizado para el componente actual conectado
                print("[INFO] {}".format(text))
            # Extrae la estadística del componente conectado y el centroide para la etiqueta actual
                x = stats[i, cv2.CC_STAT_LEFT]
                y = stats[i, cv2.CC_STAT_TOP]
                w = stats[i, cv2.CC_STAT_WIDTH]
                h = stats[i, cv2.CC_STAT_HEIGHT]
                area = stats[i, cv2.CC_STAT_AREA]
                (cX, cY) = centroids[i]
                output = images[n].copy()
           # Si se desea se imprime la imagen con un rectangulo a dibujar     
    #               cv2.rectangle(output, (x, y), (x + w, y + h), (0, 255, 0), 3)
    #               cv2.circle(output, (int(cX), int(cY)), 4, (0, 0, 255), -1)
    #             componentMask = (labels == i).astype("uint8") * 255
           # Muestra la imagen de salida y la mascara del componente conectado
    #               cv2.imshow("Output", output)
    #               cv2.imshow("Connected Component", componentMask)
        ######################################
        ######################################
        # Se corta la subimagen con las coordenadas delimitando tanto el eje "y" como el eje "x"
        ######################################
        ######################################
                crop_img = output[y:y+h, x:x+w]
        ######################################
        ######################################
        # Se eliminan los 0 para determinar la estadistica de primer orden y se añaden a su lista correspondiente
        ######################################
        ######################################    
                Rasgos = crop_img.ravel()    
                Rasgos_no_ceros = [] 
                for index in Rasgos:
                    if index!=0:
                        Rasgos_no_ceros.append(index)
            
                listMean.append(statistics.mean(Rasgos_no_ceros))
                listVariance.append(numpy.var(Rasgos_no_ceros))
                listStD.append(numpy.std(Rasgos_no_ceros))
                listKurtosis.append(kurtosis(Rasgos_no_ceros))
                listMax.append(max(Rasgos_no_ceros))
                listMin.append(min(Rasgos_no_ceros))
                listSkewness.append(skew(Rasgos_no_ceros))
                listEntropy.append(entropy(Rasgos_no_ceros))
        ######################################
        ######################################
        # Se determina la estadistica de segundo orden y se añaden a su lista correspondiente
        ######################################
        ######################################      
                
                grayImageCrop = cv2.cvtColor(crop_img, cv2.COLOR_BGR2GRAY)
                glcm = greycomatrix(grayImageCrop, [1], [0], 256, symmetric=True, normed=True)
                contrast = greycoprops(glcm, 'contrast')[0, 0]
                correlation = greycoprops(glcm, 'correlation')[0, 0]
                energy = greycoprops(glcm, 'energy')[0, 0]
                homogeneity = greycoprops(glcm, 'homogeneity')[0, 0]
                listConstrast.append(contrast)
                listCorrelation.append(correlation)
                listEnergy.append(energy)
                listHomogeneity.append(homogeneity)
                listLabel.append(label)
                plt.subplot(1,1,1),plt.imshow(crop_img,'gray')
                plt.show()
    
        ######################################
        ######################################
        # Por último se unen la listas de modo que se obtenga un Data Frame con los datos
        ######################################
        ######################################
    list_of_tuples = list(zip(listMean,listVariance,listStD,listKurtosis,listMax,listMin,listSkewness,listEntropy                          ,listConstrast,listCorrelation,listEnergy,listHomogeneity,listLabel))
    dataFrame = pd.DataFrame(list_of_tuples, columns=column_names)
    
#     print(dataFrame)
    return(dataFrame)

# %% [markdown]
# # Caracterización las imagenes de entrenamiento de lesion

# %%
pathFiles='/home/miguel/Descargas/Proyecto Innovacion/Imagenes/IMAGENES LESIONES/ENTRENAMIENTO LESION'
label = 1

dataFrameLesion = ImagesToDataFrame(pathFiles,label)
print(dataFrameLesion)
# Out:
# [INFO] Examinando el componente 2/3
# [INFO] Examinando el componente 3/3
# [INFO] Examinando el componente 2/12
# [INFO] Examinando el componente 3/12
# [INFO] Examinando el componente 4/12
# [INFO] Examinando el componente 5/12
# [INFO] Examinando el componente 6/12
# [INFO] Examinando el componente 7/12
# [INFO] Examinando el componente 8/12
# [INFO] Examinando el componente 9/12
# [INFO] Examinando el componente 10/12
# [INFO] Examinando el componente 11/12
# [INFO] Examinando el componente 12/12
# [INFO] Examinando el componente 2/9
# [INFO] Examinando el componente 3/9
# [INFO] Examinando el componente 4/9
# [INFO] Examinando el componente 5/9
# [INFO] Examinando el componente 6/9
# [INFO] Examinando el componente 7/9
# [INFO] Examinando el componente 8/9
# [INFO] Examinando el componente 9/9
# [INFO] Examinando el componente 2/5
# [INFO] Examinando el componente 3/5
# [INFO] Examinando el componente 4/5
# [INFO] Examinando el componente 5/5
# ...

# %% [markdown]
# # Caracterización las imagenes de entrenamiento de no lesion

# %%
pathFiles='/home/miguel/Descargas/Proyecto Innovacion/Imagenes/NO LESIONES/ENTRENAMIENTO NO LESION'
label = 0

dataFrameNoLesion = ImagesToDataFrame(pathFiles,label)
print(dataFrameNoLesion)
# Out:
# [INFO] Examinando el componente 2/12
# [INFO] Examinando el componente 3/12
# [INFO] Examinando el componente 4/12
# [INFO] Examinando el componente 5/12
# [INFO] Examinando el componente 6/12
# [INFO] Examinando el componente 7/12
# [INFO] Examinando el componente 8/12
# [INFO] Examinando el componente 9/12
# [INFO] Examinando el componente 10/12
# [INFO] Examinando el componente 11/12
# [INFO] Examinando el componente 12/12
# [INFO] Examinando el componente 2/13
# [INFO] Examinando el componente 3/13
# [INFO] Examinando el componente 4/13
# [INFO] Examinando el componente 5/13
# [INFO] Examinando el componente 6/13
# [INFO] Examinando el componente 7/13
# [INFO] Examinando el componente 8/13
# [INFO] Examinando el componente 9/13
# [INFO] Examinando el componente 10/13
# [INFO] Examinando el componente 11/13
# [INFO] Examinando el componente 12/13
# [INFO] Examinando el componente 13/13
# [INFO] Examinando el componente 2/17
# [INFO] Examinando el componente 3/17
# ...

# %%
# Se concatenan los datos para tener un dataframe de datos con Lesion y datos sin Lesion
frames = [dataFrameLesion, dataFrameNoLesion]

result = pd.concat(frames,ignore_index=True)

print(result)
# Out:
#      Mean   Variance       StD  Kurtosis  Max  Min  Skewness   Entropy  \
# 0     109  25.963175  5.095407  0.269083  128   99  0.755322  8.345328
# 1     109  20.617945  4.540699  0.035787  124   98  0.645385  8.627703
# 2      95  20.243487  4.499276  0.399395  112   86  0.689554  7.443160
# 3      93   2.647500  1.627114 -1.034067   96   91  0.267597  4.094192
# 4     100  43.336199  6.583024 -1.162957  115   88  0.058197  7.426171
# ..    ...        ...       ...       ...  ...  ...       ...       ...
# 205    68   1.534439  1.238725 -0.537712   71   66 -0.143654  4.430653
# 206    68   0.933333  0.966092 -0.091837   70   66  0.000000  3.806562
# 207    69   2.616780  1.617646 -0.432016   72   66 -0.180399  4.142864
# 208    67   1.271809  1.127745 -0.252480   71   66  0.503186  5.288130
# 209    68   1.539941  1.240944 -1.263488   70   66  0.235803  4.356543
#
#        Constrast  Correlation    Energy  Homogeneity  Label
# ...

# %%
# Extracción de características con RFE (Recursive Feature Elimination)
from pandas import read_csv
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
# load data
array = result.values
X = array[:,0:12]
Y = array[:,12]
# feature extraction
model = LogisticRegression(solver='lbfgs')
rfe = RFE(model, 5)
fit = rfe.fit(X, Y)
print("Num Features: %d" % fit.n_features_)
print("Selected Features: %s" % fit.support_)
print("Feature Ranking: %s" % fit.ranking_)
# Out:
# Num Features: 5
# Selected Features: [ True  True  True False False  True False  True False False False False]
# Feature Ranking: [1 1 1 4 7 1 6 1 8 3 5 2]
# /home/miguel/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:67: FutureWarning: Pass n_features_to_select=5 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# /home/miguel/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %% [markdown]
# # Ahora se seleccionan las características definidas por RFE (Recursive Feature Elimination)
#
# ## [True  True      True False     False  True False      True    False      False        False   False]
# ## [Mean   Variance  StD  Kurtosis  Max    Min  Skewness   Entropy Constrast  Correlation  Energy  Homogeneity]
#
# ## [Mean Variance StD  Min Entropy]

# %%
print(result[['Mean', 'Variance', 'StD', 'Min', 'Entropy', 'Label']])
# Out:
#      Mean   Variance       StD  Min   Entropy  Label
# 0     109  25.963175  5.095407   99  8.345328      1
# 1     109  20.617945  4.540699   98  8.627703      1
# 2      95  20.243487  4.499276   86  7.443160      1
# 3      93   2.647500  1.627114   91  4.094192      1
# 4     100  43.336199  6.583024   88  7.426171      1
# ..    ...        ...       ...  ...       ...    ...
# 205    68   1.534439  1.238725   66  4.430653      0
# 206    68   0.933333  0.966092   66  3.806562      0
# 207    69   2.616780  1.617646   66  4.142864      0
# 208    67   1.271809  1.127745   66  5.288130      0
# 209    68   1.539941  1.240944   66  4.356543      0
#
# [210 rows x 6 columns]

# %%
#Grafico Valor de los Pixeles - Mean vs Variance
fig = result[result.Label == 1].plot(kind='scatter', x='Mean', y='Variance', color='blue', label='Lesion')
result[result.Label == 0].plot(kind='scatter', x='Mean', y='Variance', color='red', label='No Lesion', ax=fig)
fig.set_xlabel('Mean')
fig.set_ylabel('Variance')
fig.set_title('Píxels - Mean vs Variance')
plt.show()

# %%
#Grafico Valor de los Pixeles - Mean vs Standard Deviation
fig = result[result.Label == 1].plot(kind='scatter', x='Mean', y='StD', color='blue', label='Lesion')
result[result.Label == 0].plot(kind='scatter', x='Mean', y='StD', color='red', label='No Lesion', ax=fig)
fig.set_xlabel('Mean')
fig.set_ylabel('Standard Deviation')
fig.set_title('Píxels - Mean vs Standard Deviation')
plt.show()

# %%
#Grafico Valor de los Pixeles - Mean vs Standard Deviation
fig = result[result.Label == 1].plot(kind='scatter', x='Mean', y='Min', color='blue', label='Lesion')
result[result.Label == 0].plot(kind='scatter', x='Mean', y='Min', color='red', label='No Lesion', ax=fig)
fig.set_xlabel('Mean')
fig.set_ylabel('Arg Min')
fig.set_title('Píxels - Mean vs Arg Min')
plt.show()

# %%
#Grafico Valor de los Pixeles - Mean vs Standard Deviation
fig = result[result.Label == 1].plot(kind='scatter', x='Mean', y='Entropy', color='blue', label='Lesion')
result[result.Label == 0].plot(kind='scatter', x='Mean', y='Entropy', color='red', label='No Lesion', ax=fig)
fig.set_xlabel('Mean')
fig.set_ylabel('Arg Min')
fig.set_title('Píxels - Mean vs Entropy')
plt.show()

# %%
#Separación de todos los datos con las características definitivas y las etiquetas.
dataSet = result[['Mean', 'Variance', 'StD', 'Min', 'Entropy', 'Label']]
X = numpy.array(dataSet.drop(['Label'], 1))
y = numpy.array(dataSet['Label'])

# %%
#Separación los datos de "train" en entrenamiento y prueba para probar los algoritmos
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print('Son {} datos para entrenamiento y {} datos para prueba'.format(X_train.shape[0], X_test.shape[0]))
# Out:
# Son 168 datos para entrenamiento y 42 datos para prueba

# %%
#Modelo de Regresión Logística
algoritmo = LogisticRegression()
algoritmo.fit(X_train, y_train)
Y_pred = algoritmo.predict(X_test)
print('Precisión Regresión Logística: {}'.format(algoritmo.score(X_train, y_train)))
# Out:
# Precisión Regresión Logística: 0.9880952380952381

# %%
#Modelo de Máquinas de Vectores de Soporte
algoritmo = SVC()
algoritmo.fit(X_train, y_train)
Y_pred = algoritmo.predict(X_test)
print('Precisión Máquinas de Vectores de Soporte: {}'.format(algoritmo.score(X_train, y_train)))
# Out:
# Precisión Máquinas de Vectores de Soporte: 0.9761904761904762

# %%
#Modelo de Vecinos más Cercanos
algoritmo = KNeighborsClassifier(n_neighbors=5)
algoritmo.fit(X_train, y_train)
Y_pred = algoritmo.predict(X_test)
print('Precisión Vecinos más Cercanos: {}'.format(algoritmo.score(X_train, y_train)))
# Out:
# Precisión Vecinos más Cercanos: 0.9761904761904762

# %%
#Modelo de Árboles de Decisión Clasificación
algoritmo = DecisionTreeClassifier()
algoritmo.fit(X_train, y_train)
Y_pred = algoritmo.predict(X_test)
print('Precisión Árboles de Decisión Clasificación: {}'.format(algoritmo.score(X_train, y_train)))
# Out:
# Precisión Árboles de Decisión Clasificación: 1.0

# %%
# Con ayuda de la biblioteca preprocessing se normalizan los datos entre 0 y 1

min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, y, test_size=0.3)

# %%
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %%
# Se dividen los datos en:

# Datos de entrenamiento 70%
# Datos para validación 15%
# Datos para pruebas 15%
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (147, 5) (31, 5) (32, 5) (147,) (31,) (32,)

# %%
model = Sequential([
    Dense(32, activation='relu', input_shape=(5,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# %%
opt = keras.optimizers.Adam(learning_rate=0.001)#default is 0.001, puede ser 0.01 o 0.1
model.compile(optimizer=opt,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
hist = model.fit(X_train, Y_train,
          batch_size=250, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 447ms/step - loss: 0.6761 - accuracy: 0.8503 - val_loss: 0.6728 - val_accuracy: 0.8387
# Epoch 2/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6712 - accuracy: 0.8367 - val_loss: 0.6702 - val_accuracy: 0.8387
# Epoch 3/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6663 - accuracy: 0.7959 - val_loss: 0.6676 - val_accuracy: 0.7742
# Epoch 4/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6616 - accuracy: 0.7823 - val_loss: 0.6650 - val_accuracy: 0.7419
# Epoch 5/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6570 - accuracy: 0.7619 - val_loss: 0.6625 - val_accuracy: 0.6774
# Epoch 6/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6526 - accuracy: 0.7279 - val_loss: 0.6600 - val_accuracy: 0.6452
# Epoch 7/100
# ...

# %%
model.evaluate(X_test, Y_test)[1]
# Out:
# 1/1 [==============================] - 0s 65ms/step - loss: 0.2764 - accuracy: 0.9062
# 0.90625

# %%
Y_test = Y_test.astype(int)
result = numpy.arange(predictions.size,dtype = int)
for indexIterator in range (0, predictions.size):
    if predictions[indexIterator] >= .5:
        result[indexIterator] = 1
    else :
        result[indexIterator] = 0
truePositive = 0
falsePositive = 0
trueNegative = 0
falseNegative = 0
for indexIterator in range (0, result.size):
    if Y_test[indexIterator] == 1 and result[indexIterator] == 1:
        truePositive = truePositive + 1
    elif Y_test[indexIterator] == 1 and result[indexIterator] == 0:
        falsePositive = falsePositive + 1
    elif Y_test[indexIterator] == 0 and result[indexIterator] == 0:
        trueNegative = trueNegative + 1
    else:
        falseNegative = falseNegative + 1

print('Verdaderos positivos',truePositive)
print('Falsos positivos',falsePositive)
print('Verdaderos negativos',trueNegative)
print('Falsos negativos',falseNegative)
# Out:
# Verdaderos positivos 16
# Falsos positivos 0
# Verdaderos negativos 13
# Falsos negativos 3

# %%
def plot_roc_curve(fpr, tpr):
    plt.plot(fpr, tpr, color='orange', label='ROC')
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('Razón de falsos positivos')
    plt.ylabel('Razón de verdaderos positivos')
    plt.title('Característica operativa del receptor curva ROC')
    plt.legend()
    plt.show()

probs = model.predict(X_test)
#probs = probs[:, 1]

auc = roc_auc_score(Y_test, probs)
print('AUC: %.2f' % auc)

fpr, tpr, thresholds = roc_curve(Y_test, probs)

plot_roc_curve(fpr, tpr)
# Out:
# AUC: 0.98

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()
